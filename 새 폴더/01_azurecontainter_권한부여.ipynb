# %% [markdown]
# # 1. 외부위치 권한부여

# %%
# %sql
-------------------------------
-- container: raw
-------------------------------
GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt019@msacademy.msai.kr`;


GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt019@msacademy.msai.kr`;


GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt004@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt009@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt019@msacademy.msai.kr`;


GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt004@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt009@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt019@msacademy.msai.kr`;


GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt004@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt009@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw`
TO `4dt019@msacademy.msai.kr`;

# %%
# %sql
-------------------------------
-- container: dmeo-raw
-------------------------------

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt019@msacademy.msai.kr`;


GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt019@msacademy.msai.kr`;


GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt004@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt009@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt019@msacademy.msai.kr`;


GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt004@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt009@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt019@msacademy.msai.kr`;


GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt004@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt009@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_demo-raw`
TO `4dt019@msacademy.msai.kr`;

# %%
# %sql
-------------------------------
-- container: raw-schedule
-------------------------------
GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt019@msacademy.msai.kr`;


GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt019@msacademy.msai.kr`;


GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt004@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt009@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt019@msacademy.msai.kr`;


GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt004@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt009@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt019@msacademy.msai.kr`;


GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt004@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt009@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_raw-schedule`
TO `4dt019@msacademy.msai.kr`;

# %%
# %sql
-------------------------------
-- container: container-operation
-------------------------------

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL TABLE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt019@msacademy.msai.kr`;


GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt004@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt009@msacademy.msai.kr`;

GRANT CREATE EXTERNAL VOLUME
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt019@msacademy.msai.kr`;


GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt004@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt009@msacademy.msai.kr`;

GRANT BROWSE
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt019@msacademy.msai.kr`;


GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt004@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt009@msacademy.msai.kr`;

GRANT READ FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt019@msacademy.msai.kr`;


GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt004@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt009@msacademy.msai.kr`;

GRANT WRITE FILES
ON EXTERNAL LOCATION `dt4_project2_team3_container-operation`
TO `4dt019@msacademy.msai.kr`;

# %%
# ==========
# 1. 파일 읽기
# ===========

# blob storage 컨테이너 이름(사용할 컨테이너 이름으로 바꾸면 됩니다.)
container = "container-operation" # 여기만 수정하세요!!!! 

# 스토리지 계정(고정)
storage_account = "dt4team3storage"

blob_path = f"abfss://{container}@{storage_account}.dfs.core.windows.net/"

files = dbutils.fs.ls(blob_path)
for f in files:
    print(f.name, f.size)
# Out:
# SCFI지수_22-24.xls 28160
# SCFI지수_25-26.xls 15872
# 월별 컨테이너 처리실적(확정)_2022.xlsx 5907
# 월별 컨테이너 처리실적(확정)_2023.xlsx 5895
# 월별 컨테이너 처리실적(확정)_2024.xlsx 5902
# 월별 컨테이너 처리실적(확정)_2025.xlsx 5904
# 월별 컨테이너 처리실적(확정)_2026.xlsx 5312

# %% [markdown]
# # 2. 카탈로그.스키마 권한 부여

# %%
# %sql
GRANT USE CATALOG
ON CATALOG `dt4_project2_team3_databricks`
TO `4dt004@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt004@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt004@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt004@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt004@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt004@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt004@msacademy.msai.kr`;

# %%
# %sql
GRANT USE CATALOG
ON CATALOG `dt4_project2_team3_databricks`
TO `4dt009@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt009@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt009@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt009@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt009@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt009@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt009@msacademy.msai.kr`;

# %%
# %sql
GRANT USE CATALOG
ON CATALOG `dt4_project2_team3_databricks`
TO `4dt019@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt019@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt019@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt019@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt019@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt019@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt019@msacademy.msai.kr`;

# %%
# %sql
GRANT USE CATALOG
ON CATALOG `dt4_project2_team3_databricks`
TO `4dt035@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt035@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt035@msacademy.msai.kr`;

GRANT USE SCHEMA
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt035@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`bronze`
TO `4dt035@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`silver`
TO `4dt035@msacademy.msai.kr`;

GRANT SELECT, MODIFY, CREATE TABLE
ON SCHEMA `dt4_project2_team3_databricks`.`gold`
TO `4dt035@msacademy.msai.kr`;
