# %%
# ===================
# 카탈로그/스키마 구조 생성
# ===================
spark.sql("USE CATALOG dt4_project2_team3_databricks")

spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")
spark.sql("CREATE SCHEMA IF NOT EXISTS sandbox_minji") 

spark.sql("SHOW SCHEMAS").show()
# Out:
# +------------------+
# |      databaseName|
# +------------------+
# |            bronze|
# |           default|
# |              gold|
# |information_schema|
# |     sandbox_minji|
# |            silver|
# +------------------+

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS sandbox_v2")
spark.sql("USE SCHEMA sandbox_v2")
# Out:
# DataFrame[]
